# %%
import pandas as pd
import random 
import names

# %%
with open('RawData.csv', 'rw') as f:
    f.writeline("")
# Out:
#         John      Staten  iazATzZqhf@gmail.com
# 0     Morris       Gomes  dISyXFCMMN@gmail.com
# 1   Patricia    Macaraeg  hhJVHujMnQ@gmail.com
# 2     Joseph        Maze  ydxnkSqvNa@gmail.com
# 3       Judi     Thomson  dgAukmYHvI@gmail.com
# 4       John        Cook  bxareIrHiT@gmail.com
# 5   Patricia       Tobar  uAqREsyYks@gmail.com
# 6        Ava      Garcia  JkAzZyFxWL@gmail.com
# 7     Nicole     Gunnels  LbJYRkvZrR@gmail.com
# 8      Kelly       Motil  jlCnTtmyDg@gmail.com
# 9       Cody      Taylor  ZNYUJsGFFh@gmail.com
# 10  Griselda   Lariviere  XyyyVNQkBt@gmail.com
# 11      Kirk       Wells  zuJgOSJegB@gmail.com
# 12      Lori      Cooper  CZJDmkdowx@gmail.com
# 13    Sharon     Hillier  HCtDplSZPK@gmail.com
# 14  Nicholas      Patten  jATXoENGQg@gmail.com
# 15      Jack       Arias  ZFMyNoEwCp@gmail.com
# 16   Deborah      Luongo  rtaXFFQAIE@gmail.com
# 17    Robert     Londner  xlAOtONHiP@gmail.com
# 18       Max     Johnson  otcyApWijn@gmail.com
# ...
